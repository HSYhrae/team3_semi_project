# %% [markdown]
# <a href="https://colab.research.google.com/github/HSYhrae/team3_semi_project/blob/data/%EC%84%9C%EC%9A%B8%EC%8B%9C_%EB%A7%A4%EB%A7%A4_%EC%8B%A4%EA%B1%B0%EB%9E%98%EA%B0%80_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 한글폰트 적용

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (18.8 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.pyplot as plt
plt.rc("font", family="NanumGothic") # 라이브러리 불러오기와 함께 한번만 실행

plt.plot([1, 2, 3])
plt.title("한글")
plt.show()

# %% [markdown]
# ## 구글 드라이브 연동

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 데이터 불러오기 및 라이브러리 임포트

# %%
'''
# 인코딩 확인 및 변환 시 참고 코드
# 데이터 전처리 코드에선 사용하지 않음 !!

import chardet # 인코딩 확인
import codecs  # 인코딩 변환

# 디렉토리 경로 설정
directory_path = '/content/drive/MyDrive/data/3team_project/전월세가'

# 2011년부터 2021년까지의 파일 불러오기 위한 반복문
for year in range(2011, 2022):
    # 파일명 생성
    file_name = f'/서울특별시_전월세가_{year}.txt'

    # 파일의 전체 경로 생성
    file_path = f'{directory_path}{file_name}'

    try:
        # 파일 인코딩 확인
        with open(file_path, 'rb') as file:
            detector = chardet.universaldetector.UniversalDetector()
            for line in file.readlines():
                detector.feed(line)
                if detector.done:
                    break
            detector.close()
            file_encoding = detector.result['encoding']

        # 인코딩 확인
        print(f'{year}년 데이터 파일의 인코딩: {file_encoding}')

        # 파일을 UTF-8로 변환하여 새 파일로 저장
        output_file_path = f'{directory_path}/서울특별시_전월세가_{year}_utf8.txt'
        with codecs.open(file_path, 'r', encoding=file_encoding) as file:
            content = file.read()
            with codecs.open(output_file_path, 'w', encoding='utf-8') as output_file:
                output_file.write(content)

        print(f'{year}년 데이터 파일을 UTF-8로 변환한 파일을 {output_file_path}에 저장했습니다.')
        print('\n')
    except FileNotFoundError:
        print(f'{year}년 데이터 파일이 존재하지 않습니다.')
'''
# Out:
# "\n# 인코딩 확인 및 변환 시 참고 코드\n# 데이터 전처리 코드에선 사용하지 않음 !!\n\nimport chardet # 인코딩 확인\nimport codecs  # 인코딩 변환\n\n# 디렉토리 경로 설정\ndirectory_path = '/content/drive/MyDrive/data/3team_project/전월세가'\n\n# 2011년부터 2021년까지의 파일 불러오기 위한 반복문\nfor year in range(2011, 2022):\n    # 파일명 생성\n    file_name = f'/서울특별시_전월세가_{year}.txt'\n\n    # 파일의 전체 경로 생성\n    file_path = f'{directory_path}{file_name}'\n\n    try:\n        # 파일 인코딩 확인\n        with open(file_path, 'rb') as file:\n            detector = chardet.universaldetector.UniversalDetector()\n            for line in file.readlines():\n                detector.feed(line)\n                if detector.done:\n                    break\n            detector.close()\n            file_encoding = detector.result['encoding']\n\n        # 인코딩 확인\n        print(f'{year}년 데이터 파일의 인코딩: {file_encoding}')\n\n        # 파일을 UTF-8로 변환하여 새 파일로 저장\n        output_file_path = f'{directory_path}/서울특별시_전월세가_{year}_utf8.txt'\n        with c
# ...

# %%
import chardet # 인코딩 확인
import os
# 파일 경로 지정
check_file_path = '/content/drive/MyDrive/data/3team_project/서울시_매매가/서울시 부동산 실거래가 정보_2011년.csv'

# 파일의 인코딩 체크
with open(check_file_path, 'rb') as file:
  result = chardet.detect(file.read())
  print(f'File: {check_file_path}, Encoding: {result["encoding"]}, Confidence: {result["confidence"]}')
# Out:
# File: /content/drive/MyDrive/data/3team_project/서울시_매매가/서울시 부동산 실거래가 정보_2011년.csv, Encoding: EUC-KR, Confidence: 0.99

# %%
import os
import subprocess
import pandas as pd

directory_path = '/content/drive/MyDrive/data/3team_project/서울시_매매가'

# 빈 데이터프레임 생성
seoul_Sell_data = pd.DataFrame()

# 2011년부터 2021년까지의 파일 불러오기 위한 반복문
for year in range(2011, 2023):
  # 파일명 생성
  file_name = f'/서울시 부동산 실거래가 정보_{year}년.csv'

  # 파일의 전체 경로 생성
  file_path = f'{directory_path}{file_name}'

  try :
    # 파일 불러오기(텍스트 파일을 읽어오는 로직)
    with open(file_path, 'r', encoding='EUC-KR') as file:
      data = pd.read_csv(file, sep=',', engine='python')
      seoul_Sell_data = pd.concat([seoul_Sell_data, data], ignore_index=True)

      # 데이터 프레임을 사용하여 원하는 작업 수행
      # 데이터 프레임을 출력
      print(f'{year}년 데이터:')
      print(seoul_Sell_data.head())  # 데이터 프레임 출력
      print('\n')
  except FileNotFoundError:
    print(f'{year}년 데이터 파일이 존재하지 않습니다.') # 누락 데이터 확인
# Out:
# 2011년 데이터:
#    접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명     본번   부번            건물명  ...  \
# 0  2011  11260  중랑구  10400   묵동   1.0    대지  170.0  1.0        묵동자이2단지  ...
# 1  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)  ...
# 2  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)  ...
# 3  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)  ...
# 4  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)  ...
#
#    물건금액(만원)  건물면적(㎡)  토지면적(㎡)    층  권리구분 취소일    건축년도   건물용도 신고구분  \
# 0     59324   111.73     0.00  9.0   분양권 NaN     0.0    아파트  NaN
# 1     17350    53.19    32.60  5.0   NaN NaN  2011.0  연립다세대  NaN
# 2     19600    59.65    36.55  3.0   NaN NaN  2011.0  연립다세대  NaN
# 3     17300    53.19    32.60  5.0   NaN NaN  2011.0  연립다세대  NaN
# 4     15550    47.66    29.21  3.0   NaN NaN  2011.0  연립다세대  NaN
#
#    신고한 개업공인중개사 시군구명
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
seoul_Sell_data.info()
# 결측치 없는 컬럼 종류
# 접수연도, 자치구명, 자치구코드, 계약일, 물건금액(만원), 건물면적(㎡), 토지면적(㎡), 건물용도
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1900593 entries, 0 to 1900592
# Data columns (total 21 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   접수연도              int64
#  1   자치구코드             int64
#  2   자치구명              object
#  3   법정동코드             int64
#  4   법정동명              object
#  5   지번구분              float64
#  6   지번구분명             object
#  7   본번                object
#  8   부번                float64
#  9   건물명               object
#  10  계약일               int64
#  11  물건금액(만원)          int64
#  12  건물면적(㎡)           float64
#  13  토지면적(㎡)           float64
#  14  층                 float64
#  15  권리구분              object
#  16  취소일               float64
#  17  건축년도              float64
#  18  건물용도              object
#  19  신고구분              object
#  20  신고한 개업공인중개사 시군구명  object
# dtypes: float64(7), int64(5), object(9)
# memory usage: 304.5+ MB

# %%
# DataFrame 출력 설정 변경
pd.set_option('display.max_columns', None)
seoul_Sell_data.head(3)
# Out:
#    접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명     본번   부번            건물명  \
# 0  2011  11260  중랑구  10400   묵동   1.0    대지  170.0  1.0        묵동자이2단지
# 1  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
# 2  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
#
#         계약일  물건금액(만원)  건물면적(㎡)  토지면적(㎡)    층 권리구분  취소일    건축년도   건물용도 신고구분  \
# 0  20120503     59324   111.73     0.00  9.0  분양권  NaN     0.0    아파트  NaN
# 1  20120102     17350    53.19    32.60  5.0  NaN  NaN  2011.0  연립다세대  NaN
# 2  20120102     19600    59.65    36.55  3.0  NaN  NaN  2011.0  연립다세대  NaN
#
#   신고한 개업공인중개사 시군구명
# 0              NaN
# 1              NaN
# 2              NaN

# %% [markdown]
# ### 필요없는 컬럼 삭제

# %%
# 삭제할 컬럼 범위 지정
columns_to_drop = ['토지면적(㎡)', '권리구분', '신고구분', '신고한 개업공인중개사 시군구명']

# 컬럼 삭제
seoul_Sell_data = seoul_Sell_data.drop(columns=columns_to_drop)
seoul_Sell_data.head(3)
# Out:
#    접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명     본번   부번            건물명  \
# 0  2011  11260  중랑구  10400   묵동   1.0    대지  170.0  1.0        묵동자이2단지
# 1  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
# 2  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
#
#         계약일  물건금액(만원)  건물면적(㎡)    층  취소일    건축년도   건물용도
# 0  20120503     59324   111.73  9.0  NaN     0.0    아파트
# 1  20120102     17350    53.19  5.0  NaN  2011.0  연립다세대
# 2  20120102     19600    59.65  3.0  NaN  2011.0  연립다세대

# %% [markdown]
# - 메모 09. 04 10:43 -

# %%
seoul_Sell_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1900593 entries, 0 to 1900592
# Data columns (total 17 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   접수연도      int64
#  1   자치구코드     int64
#  2   자치구명      object
#  3   법정동코드     int64
#  4   법정동명      object
#  5   지번구분      float64
#  6   지번구분명     object
#  7   본번        object
#  8   부번        float64
#  9   건물명       object
#  10  계약일       int64
#  11  물건금액(만원)  int64
#  12  건물면적(㎡)   float64
#  13  층         float64
#  14  취소일       float64
#  15  건축년도      float64
#  16  건물용도      object
# dtypes: float64(6), int64(5), object(6)
# memory usage: 246.5+ MB

# %%
# DataFrame을 CSV 파일, utf-8 형식으로 저장
seoul_Sell_data.to_csv('/content/drive/MyDrive/data/3team_project/서울시_매매가/서울특별시_매매_실거래가_총합본.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### 새로 데이터 불러오기

# %%
seoul_Sell_data = pd.read_csv('/content/drive/MyDrive/data/3team_project/서울시_매매가/서울특별시_매매_실거래가_총합본.csv')
seoul_Sell_data
# Out:
# <ipython-input-8-93e9a40f0a79>:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   seoul_Sell_data = pd.read_csv('/content/drive/MyDrive/data/3team_project/서울시_매매가/서울특별시_매매_실거래가_총합본.csv')
#          접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명      본번    부번  \
# 0        2011  11260  중랑구  10400   묵동   1.0    대지   170.0   1.0
# 1        2011  11320  도봉구  10600  방학동   1.0    대지   611.0   9.0
# 2        2011  11320  도봉구  10600  방학동   1.0    대지   611.0   9.0
# 3        2011  11320  도봉구  10600  방학동   1.0    대지   611.0   9.0
# 4        2011  11320  도봉구  10600  방학동   1.0    대지   611.0   9.0
# ...       ...    ...  ...    ...  ...   ...   ...     ...   ...
# 1900588  2022  11290  성북구  13400  길음동   1.0    대지   508.0  16.0
# 1900589  2022  11650  서초구  10800  서초동   1.0    대지  1315.0   0.0
# 1900590  2022  11710  송파구  11300  거여동   1.0    대지   234.0   0.0
# ...

# %% [markdown]
# ### 취소된 실거래 데이터 삭제

# %%
# 취소일 결측치가 아닌 값들 실거래 데이터에서 삭제해야될 데이터들
# 취소일이 NAN이 아닌 행 삭제 // 거래취소 개수 8524개
seoul_Sell_data = seoul_Sell_data[seoul_Sell_data['취소일'].isna()]
seoul_Sell_data.head(5)
# Out:
#    접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명     본번   부번            건물명  \
# 0  2011  11260  중랑구  10400   묵동   1.0    대지  170.0  1.0        묵동자이2단지
# 1  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
# 2  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
# 3  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
# 4  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
#
#         계약일  물건금액(만원)  건물면적(㎡)    층  취소일    건축년도   건물용도
# 0  20120503     59324   111.73  9.0  NaN     0.0    아파트
# 1  20120102     17350    53.19  5.0  NaN  2011.0  연립다세대
# 2  20120102     19600    59.65  3.0  NaN  2011.0  연립다세대
# 3  20120102     17300    53.19  5.0  NaN  2011.0  연립다세대
# 4  20120102     15550    47.66  3.0  NaN  2011.0  연립다세대

# %%
seoul_Sell_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1870607 entries, 0 to 1900592
# Data columns (total 17 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   접수연도      int64
#  1   자치구코드     int64
#  2   자치구명      object
#  3   법정동코드     int64
#  4   법정동명      object
#  5   지번구분      float64
#  6   지번구분명     object
#  7   본번        object
#  8   부번        float64
#  9   건물명       object
#  10  계약일       int64
#  11  물건금액(만원)  int64
#  12  건물면적(㎡)   float64
#  13  층         float64
#  14  취소일       float64
#  15  건축년도      float64
#  16  건물용도      object
# dtypes: float64(6), int64(5), object(6)
# memory usage: 256.9+ MB

# %% [markdown]
# ### 필요없는 취소일 컬럼 삭제
# - 필요없는 취소된 데이터를 걸러냈으니 컬럼도 필요 없어짐

# %%
seoul_Sell_data = seoul_Sell_data.drop('취소일', axis = 1)
seoul_Sell_data.head(3)
# Out:
#    접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명     본번   부번            건물명  \
# 0  2011  11260  중랑구  10400   묵동   1.0    대지  170.0  1.0        묵동자이2단지
# 1  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
# 2  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
#
#         계약일  물건금액(만원)  건물면적(㎡)    층    건축년도   건물용도
# 0  20120503     59324   111.73  9.0     0.0    아파트
# 1  20120102     17350    53.19  5.0  2011.0  연립다세대
# 2  20120102     19600    59.65  3.0  2011.0  연립다세대

# %%
# 결측치 없음을 확인
seoul_Sell_data.isnull().sum()
# Out:
# 접수연도             0
# 자치구코드            0
# 자치구명             0
# 법정동코드            0
# 법정동명             0
# 지번구분        144407
# 지번구분명       144407
# 본번          144386
# 부번          144386
# 건물명         144373
# 계약일              0
# 물건금액(만원)         0
# 건물면적(㎡)          0
# 층           144254
# 건축년도          4513
# 건물용도             0
# dtype: int64

# %%
# 행 데이터 삭제 처리 하였으니 인덱스 값 초기화
seoul_Sell_data.reset_index(drop=True, inplace=True)
seoul_Sell_data.head(3)
# Out:
#    접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명     본번   부번            건물명  \
# 0  2011  11260  중랑구  10400   묵동   1.0    대지  170.0  1.0        묵동자이2단지
# 1  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
# 2  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
#
#         계약일  물건금액(만원)  건물면적(㎡)    층    건축년도   건물용도
# 0  20120503     59324   111.73  9.0     0.0    아파트
# 1  20120102     17350    53.19  5.0  2011.0  연립다세대
# 2  20120102     19600    59.65  3.0  2011.0  연립다세대

# %% [markdown]
# ### 계약일 기준으로 계약년도, 계약월 컬럼 생성

# %%
# "계약일" 컬럼을 날짜 형식으로 변환
seoul_Sell_data['계약일'] = pd.to_datetime(seoul_Sell_data['계약일'], format='%Y%m%d')

# "계약년도"와 "계약월" 컬럼 추가
seoul_Sell_data['계약년도'] = seoul_Sell_data['계약일'].dt.year
seoul_Sell_data['계약월'] = seoul_Sell_data['계약일'].dt.month

# 맨 우측에 계약년도, 계약월 컬럼 생성된 것 확인
seoul_Sell_data.head(3)
# Out:
#    접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명     본번   부번            건물명  \
# 0  2011  11260  중랑구  10400   묵동   1.0    대지  170.0  1.0        묵동자이2단지
# 1  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
# 2  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
#
#          계약일  물건금액(만원)  건물면적(㎡)    층    건축년도   건물용도  계약년도  계약월
# 0 2012-05-03     59324   111.73  9.0     0.0    아파트  2012    5
# 1 2012-01-02     17350    53.19  5.0  2011.0  연립다세대  2012    1
# 2 2012-01-02     19600    59.65  3.0  2011.0  연립다세대  2012    1

# %%
# 계약년도, 계약월 int64 값인지 확인
seoul_Sell_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1870607 entries, 0 to 1870606
# Data columns (total 18 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   접수연도      int64
#  1   자치구코드     int64
#  2   자치구명      object
#  3   법정동코드     int64
#  4   법정동명      object
#  5   지번구분      float64
#  6   지번구분명     object
#  7   본번        object
#  8   부번        float64
#  9   건물명       object
#  10  계약일       datetime64[ns]
#  11  물건금액(만원)  int64
#  12  건물면적(㎡)   float64
#  13  층         float64
#  14  건축년도      float64
#  15  건물용도      object
#  16  계약년도      int64
#  17  계약월       int64
# dtypes: datetime64[ns](1), float64(5), int64(6), object(6)
# memory usage: 256.9+ MB

# %% [markdown]
# ### 제곱미터당가, 평당가 컬럼 만들기

# %%
# 면적당전세가 계산 및 소수점 2자리 까지 표현
seoul_Sell_data['면적당매매가'] = round(seoul_Sell_data['물건금액(만원)'] / seoul_Sell_data['건물면적(㎡)'], 2)

# 평당전세가 계산 및 소수점 2자리 까지 표현
seoul_Sell_data['평당매매가'] = round(seoul_Sell_data['물건금액(만원)'] / seoul_Sell_data['건물면적(㎡)'] * 0.3025, 2)

# 거래량 컬럼 만들기
seoul_Sell_data['거래량'] = 1

seoul_Sell_data.head(3)
# Out:
#    접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명     본번   부번            건물명  \
# 0  2011  11260  중랑구  10400   묵동   1.0    대지  170.0  1.0        묵동자이2단지
# 1  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
# 2  2011  11320  도봉구  10600  방학동   1.0    대지  611.0  9.0  풀내음파크빌(611-9)
#
#          계약일  물건금액(만원)  건물면적(㎡)    층    건축년도   건물용도  계약년도  계약월  면적당매매가  \
# 0 2012-05-03     59324   111.73  9.0     0.0    아파트  2012    5  530.96
# 1 2012-01-02     17350    53.19  5.0  2011.0  연립다세대  2012    1  326.19
# 2 2012-01-02     19600    59.65  3.0  2011.0  연립다세대  2012    1  328.58
#
#     평당매매가  거래량
# 0  160.61    1
# 1   98.67    1
# 2   99.40    1

# %%
seoul_Sell_data.isnull().sum()
# Out:
# 접수연도             0
# 자치구코드            0
# 자치구명             0
# 법정동코드            0
# 법정동명             0
# 지번구분        144407
# 지번구분명       144407
# 본번          144386
# 부번          144386
# 건물명         144373
# 계약일              0
# 물건금액(만원)         0
# 건물면적(㎡)          0
# 층           144254
# 건축년도          4513
# 건물용도             0
# 계약년도             0
# 계약월              0
# 면적당매매가           0
# 평당매매가            0
# 거래량              0
# dtype: int64

# %% [markdown]
# '부번' 결측치 제거

# %%
seoul_Sell_data.dropna(subset=['부번'], inplace=True)
seoul_Sell_data.dropna(subset=['지번구분'], inplace=True)

# %%
# 결측치 없음을 확인
seoul_Sell_data.isnull().sum()
# Out:
# 접수연도           0
# 자치구코드          0
# 자치구명           0
# 법정동코드          0
# 법정동명           0
# 지번구분           0
# 지번구분명          0
# 본번             0
# 부번             0
# 건물명          140
# 계약일            0
# 물건금액(만원)       0
# 건물면적(㎡)        0
# 층              0
# 건축년도        3823
# 건물용도           0
# 계약년도           0
# 계약월            0
# 면적당매매가         0
# 평당매매가          0
# 거래량            0
# dtype: int64

# %% [markdown]
# ### 법정동코드, 지번구분코드, 본번, 부번 컬럼 데이터 타입 int로 변경

# %%
# 아래 컬럼들 정수로 변환
seoul_Sell_data['법정동코드'] = seoul_Sell_data['법정동코드'].astype(int)
seoul_Sell_data['본번'] = seoul_Sell_data['본번'].astype(float)
seoul_Sell_data['본번'] = seoul_Sell_data['본번'].astype(int)
seoul_Sell_data['부번'] = seoul_Sell_data['부번'].astype(int)
seoul_Sell_data['지번구분'] = seoul_Sell_data['지번구분'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-32faffbaaa10> in <cell line: 3>()
#       1 # 아래 컬럼들 정수로 변환
#       2 seoul_Sell_data['법정동코드'] = seoul_Sell_data['법정동코드'].astype(int)
# ----> 3 seoul_Sell_data['본번'] = seoul_Sell_data['본번'].astype(float)
#       4 seoul_Sell_data['본번'] = seoul_Sell_data['본번'].astype(int)
#       5 seoul_Sell_data['부번'] = seoul_Sell_data['부번'].astype(int)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# ...

# %%
seoul_Sell_data.reset_index(drop=True, inplace=True)
seoul_Sell_data.tail(1)
# Out:
#          접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명     본번   부번             건물명  \
# 1726199  2022  11710  송파구  11300  거여동   1.0    대지  234.0  0.0  e편한세상 송파 파크센트럴
#
#                계약일  물건금액(만원)  건물면적(㎡)     층  건축년도 건물용도  계약년도  계약월   면적당매매가  \
# 1726199 2018-01-24     69905    59.96  32.0   0.0  아파트  2018    1  1165.86
#
#           평당매매가  거래량
# 1726199  352.67    1

# %%
len(seoul_Sell_data.index)
# Out:
# 1726200

# %% [markdown]
# ### 본번 코드 중에 문자가 있어 오류가 발생

# %%
lst = []
for i in range(0, len(seoul_Sell_data.index)):
    if seoul_Sell_data.loc[i, '본번'] == '00C1':
        lst.append(i)
print(len(lst))
# Out:
# 57

# %%
lst = []
for i in range(0, len(seoul_Sell_data.index)):
    if seoul_Sell_data.loc[i, '본번'] == '000C':
        lst.append(i)
print(len(lst))
# Out:
# 2

# %%
lst = []
for i in range(0, len(seoul_Sell_data.index)):
    if seoul_Sell_data.loc[i, '본번'] == '00A1':
        lst.append(i)
print(len(lst))
# Out:
# 4

# %% [markdown]
# ### '본번'컬럼에서 '00C1' 값을 가진 행 삭제

# %%
seoul_Sell_data = seoul_Sell_data[seoul_Sell_data['본번'] != '00C1']
seoul_Sell_data = seoul_Sell_data[seoul_Sell_data['본번'] != '000C']
seoul_Sell_data = seoul_Sell_data[seoul_Sell_data['본번'] != '00A1']

# %%
seoul_Sell_data.reset_index(drop=True, inplace=True)
seoul_Sell_data.tail(1)
# Out:
#          접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명     본번   부번             건물명  \
# 1726136  2022  11710  송파구  11300  거여동   1.0    대지  234.0  0.0  e편한세상 송파 파크센트럴
#
#                계약일  물건금액(만원)  건물면적(㎡)     층  건축년도 건물용도  계약년도  계약월   면적당매매가  \
# 1726136 2018-01-24     69905    59.96  32.0   0.0  아파트  2018    1  1165.86
#
#           평당매매가  거래량
# 1726136  352.67    1

# %%
# 아래 컬럼들 정수로 변환
seoul_Sell_data['법정동코드'] = seoul_Sell_data['법정동코드'].astype(int)
seoul_Sell_data['본번'] = seoul_Sell_data['본번'].astype(float)
seoul_Sell_data['본번'] = seoul_Sell_data['본번'].astype(int)
seoul_Sell_data['부번'] = seoul_Sell_data['부번'].astype(int)
seoul_Sell_data['지번구분'] = seoul_Sell_data['지번구분'].astype(int)

# %%
# 아래 컬럼들 문자열로 변환
seoul_Sell_data['법정동코드'] = seoul_Sell_data['법정동코드'].astype(str)
seoul_Sell_data['본번'] = seoul_Sell_data['본번'].astype(str)
seoul_Sell_data['부번'] = seoul_Sell_data['부번'].astype(str)
seoul_Sell_data['지번구분'] = seoul_Sell_data['지번구분'].astype(str)

# %% [markdown]
# ### 주소 컬럼, 위도, 경도 컬럼 만들기

# %%
seoul_Sell_data['주소'] = ''
seoul_Sell_data['위도'] = 37
seoul_Sell_data['경도'] = 126
seoul_Sell_data.head()
# Out:
#    접수연도  자치구코드 자치구명  법정동코드 법정동명 지번구분 지번구분명   본번 부번            건물명        계약일  \
# 0  2011  11260  중랑구  10400   묵동    1    대지  170  1        묵동자이2단지 2012-05-03
# 1  2011  11320  도봉구  10600  방학동    1    대지  611  9  풀내음파크빌(611-9) 2012-01-02
# 2  2011  11320  도봉구  10600  방학동    1    대지  611  9  풀내음파크빌(611-9) 2012-01-02
# 3  2011  11320  도봉구  10600  방학동    1    대지  611  9  풀내음파크빌(611-9) 2012-01-02
# 4  2011  11320  도봉구  10600  방학동    1    대지  611  9  풀내음파크빌(611-9) 2012-01-02
#
#    물건금액(만원)  건물면적(㎡)    층    건축년도   건물용도  계약년도  계약월  면적당매매가   평당매매가  거래량 주소  \
# 0     59324   111.73  9.0     0.0    아파트  2012    5  530.96  160.61    1
# 1     17350    53.19  5.0  2011.0  연립다세대  2012    1  326.19   98.67    1
# 2     19600    59.65  3.0  2011.0  연립다세대  2012    1  328.58   99.40    1
# 3     17300    53.19  5.0  2011.0  연립다세대  2012    1  325.25   98.39    1
# 4     15550    47.66  3.0  2011.0  연립다세대  2012    1  326.27   98.70    1
#
#    위도   경도
# 0  37  126
# 1  37  126
# 2  37  126
# ...

# %%
# 부번이 0 이면 부번을 제외하고 주소를 정의하기
def get_address(row):
    if row["부번"] == '0':
        return row["자치구명"] + " " + row["법정동명"] + " " + row["본번"]
    else:
        return row["자치구명"] + " " + row["법정동명"] + " " + row["본번"] + "-" + row["부번"]

# %%
seoul_Sell_data["주소"] = seoul_Sell_data.apply(get_address, axis=1)

# %%
seoul_Sell_data.head(5)
# Out:
#    접수연도  자치구코드 자치구명  법정동코드 법정동명 지번구분 지번구분명   본번 부번            건물명        계약일  \
# 0  2011  11260  중랑구  10400   묵동    1    대지  170  1        묵동자이2단지 2012-05-03
# 1  2011  11320  도봉구  10600  방학동    1    대지  611  9  풀내음파크빌(611-9) 2012-01-02
# 2  2011  11320  도봉구  10600  방학동    1    대지  611  9  풀내음파크빌(611-9) 2012-01-02
# 3  2011  11320  도봉구  10600  방학동    1    대지  611  9  풀내음파크빌(611-9) 2012-01-02
# 4  2011  11320  도봉구  10600  방학동    1    대지  611  9  풀내음파크빌(611-9) 2012-01-02
#
#    물건금액(만원)  건물면적(㎡)    층    건축년도   건물용도  계약년도  계약월  면적당매매가   평당매매가  거래량  \
# 0     59324   111.73  9.0     0.0    아파트  2012    5  530.96  160.61    1
# 1     17350    53.19  5.0  2011.0  연립다세대  2012    1  326.19   98.67    1
# 2     19600    59.65  3.0  2011.0  연립다세대  2012    1  328.58   99.40    1
# 3     17300    53.19  5.0  2011.0  연립다세대  2012    1  325.25   98.39    1
# 4     15550    47.66  3.0  2011.0  연립다세대  2012    1  326.27   98.70    1
#
#               주소  위도   경도
# 0   중랑구 묵동 170-1  37  126
# ...

# %%
test = seoul_Sell_data

# %% [markdown]
# ## 구글 맵 api 활용

# %%
# !pip install -U googlemaps
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40713 sha256=66fd516542047f41b7636d85993ac3013456e58ab47c1f6abba63098915a4122
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# ...

# %%
import googlemaps
from datetime import datetime

apikey = 'AIzaSyAfImD3Zyc6uVX_WwKM6b4X27IA3G6eOe4'

def getLoc(addr):
    gmaps = googlemaps.Client(key='AIzaSyAfImD3Zyc6uVX_WwKM6b4X27IA3G6eOe4')
    geocode_result = gmaps.geocode(addr)
    n_lat = geocode_result[0]['geometry']['location']['lat']
    n_lng = geocode_result[0]['geometry']['location']['lng']
    loc = {'lat':n_lat, 'lng':n_lng}
    return loc

# 함수 설정을 통해 구글 지오코드 서비스로 위도 경도에 대한 데이터 가져온 후
# 실거래가 데이터 프레임의 "주소" 컬럼의 주소 값들을 기반으로 위도, 경도 위치 데이터 받은 후
# "위도", "경도"에 컬럼값 위치 데이터 넣기

# %%
sampled_df = seoul_Sell_data.sample(n=30000, random_state=42) # random_state = 재현가능성
sampled_df = sampled_df.reset_index(drop=True)
sampled_df.head(3)
# Out:
#    접수연도  자치구코드 자치구명  법정동코드   법정동명 지번구분 지번구분명   본번 부번        건물명        계약일  \
# 0  2022  11290  성북구  10300    돈암동    1    대지  642  0    돈암동해피트리 2022-06-18
# 1  2017  11350  노원구  10600    중계동    1    대지  505  0    롯데(505) 2017-07-21
# 2  2014  11140   중구  14500  광희동1가    1    대지  143  2  (143-2)\t 2014-12-09
#
#    물건금액(만원)  건물면적(㎡)    층    건축년도  건물용도  계약년도  계약월  면적당매매가   평당매매가  거래량  \
# 0    124000   132.43  8.0  2013.0   아파트  2022    6  936.34  283.24    1
# 1     43500    72.49  5.0  1989.0   아파트  2017    7  600.08  181.53    1
# 2     14000    24.96  7.0  2001.0  오피스텔  2014   12  560.90  169.67    1
#
#                주소    위도     경도
# 0     성북구 돈암동 642  37.0  126.0
# 1     노원구 중계동 505  37.0  126.0
# 2  중구 광희동1가 143-2  37.0  126.0

# %%
sampled_df.tail(1)
# Out:
#        접수연도  자치구코드 자치구명  법정동코드 법정동명 지번구분 지번구분명   본번 부번        건물명        계약일  \
# 29999  2019  11530  구로구  10700  개봉동    1    대지  489  0  개봉동현대아이파크 2019-11-18
#
#        물건금액(만원)  건물면적(㎡)     층    건축년도 건물용도  계약년도  계약월  면적당매매가  평당매매가  거래량  \
# 29999     67000    84.98  16.0  2006.0  아파트  2019   11  788.42  238.5    1
#
#                 주소    위도     경도
# 29999  구로구 개봉동 489  37.0  126.0

# %%
for i in sampled_df.index:
    find = sampled_df.loc[i, "주소"]
    sub_lat = getLoc(find)['lat']
    sub_long = getLoc(find)['lng']
    sampled_df.loc[i, '위도'] = sub_lat
    sampled_df.loc[i, '경도'] = sub_long

sampled_df.head(3)

# %%
sampled_df.tail(3)
# Out:
#       접수연도  자치구코드 자치구명  법정동코드 법정동명 지번구분 지번구분명   본번 부번        건물명        계약일  \
# 2997  2013  11290  성북구  10300  돈암동    1    대지  609  1  한진(609-1) 2013-06-28
# 2998  2018  11590  동작구  10400   본동    1    대지  492  0      삼성래미안 2018-08-10
# 2999  2017  11710  송파구  10300  풍납동    1    대지  401  1         쌍용 2017-05-09
#
#       물건금액(만원)  건물면적(㎡)     층    건축년도 건물용도  계약년도  계약월  면적당매매가   평당매매가  거래량  \
# 2997     30000    84.87  19.0  1998.0  아파트  2013    6  353.48  106.93    1
# 2998     81000    84.23   6.0  2004.0  아파트  2018    8  961.65  290.90    1
# 2999     57200    84.86   9.0  1994.0  아파트  2017    5  674.05  203.90    1
#
#                  주소         위도          경도
# 2997  성북구 돈암동 609-1  37.594808  127.010319
# 2998     동작구 본동 492  37.510016  126.950080
# 2999  송파구 풍납동 401-1  37.527251  127.117703

# %%
# DataFrame을 CSV 파일, utf-8 형식으로 저장
sampled_df.to_csv('/content/drive/MyDrive/data/3team_project/서울시_매매가/서울특별시_매매_실거래가_3만개.csv', encoding='utf-8', index=False)

# %% [markdown]
# # 주성님 요청 년도별, 월별, 건물용도별, 주소별 평균 값을 구하기

# %%
seoul_Sell_data.head(1)
# Out:
#    접수연도  자치구코드 자치구명  법정동코드 법정동명 지번구분 지번구분명   본번 부번      건물명        계약일  \
# 0  2011  11260  중랑구  10400   묵동    1    대지  170  1  묵동자이2단지 2012-05-03
#
#    물건금액(만원)  건물면적(㎡)    층  건축년도 건물용도  계약년도  계약월  면적당매매가   평당매매가  거래량  \
# 0     59324   111.73  9.0   0.0  아파트  2012    5  530.96  160.61    1
#
#              주소  위도   경도
# 0  중랑구 묵동 170-1  37  126

# %%
group_Sell = seoul_Sell_data.groupby(['계약년도', '계약월', '주소', '건물용도']).agg({'물건금액(만원)': 'mean'})
group_Sell.reset_index(inplace =True)

# %%
group_Sell
# Out:
#         계약년도  계약월               주소   건물용도  물건금액(만원)
# 0       2006    1    양천구 신월동 42-13  연립다세대    7000.0
# 1       2006   10      용산구 한남동 807    아파트   86000.0
# 2       2007    1   서초구 서초동 1488-5    아파트   45000.0
# 3       2007    3      노원구 공릉동 230    아파트   29900.0
# 4       2007    8    강서구 화곡동 354-2  연립다세대   14000.0
# ...      ...  ...              ...    ...       ...
# 788889  2023    1  강남구 개포동 1165-16  연립다세대   69000.0
# 788890  2023    1  강동구 천호동 167-153   오피스텔   22500.0
# 788891  2023    1   성동구 용답동 238-12   오피스텔   13500.0
# 788892  2023    2      광진구 자양동 860    아파트  105000.0
# 788893  2023    4  중랑구 면목동 173-164  연립다세대   16000.0
#
# [788894 rows x 5 columns]

# %%
type(group_Sell)
group_Sell.to_csv('/content/drive/MyDrive/data/3team_project/서울시_매매가/서울시_매매_groupby버전.csv', encoding='utf-8', index=False)
